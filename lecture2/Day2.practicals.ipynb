# %% [markdown]
# # <span style="color:#2563EB"><strong>Day 2 — Model Performance Uncertainty Reporting</strong></span>
#
# This notebook contains three practical exercises:
#
# - Practical 2.1: Standard deviation and standard error of DSC
# - Practical 2.2: Bootstrap confidence intervals for individual model performance
# - Practical 2.3: Bootstrap confidence intervals for performance differences between models
#
# The aim is to quantify uncertainty in model performance estimates and in comparisons between algorithms.

# %%
# Required packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # <span style="color:#2563EB"><strong>Practical 2.1: Standard Deviation and Standard Error of DSC</strong></span>
#
# In this practical, you will work with two example datasets of Dice Similarity Coefficient (**DSC**) values.
#
# Each row corresponds to one test case, and the column `DSC` contains the DSC score for that case.

# %% [markdown]
# <div style="background-color:#EFF6FF; padding:12px; border-radius:8px">
#
# <span style="color:#2563EB"><strong>Datasets</strong></span>
#
# | Dataset | Filename | Sample size |
# |---|---|---:|
# | Dataset A | `day2_practical_2_1_dataset_n25_left_skew.csv` | 25 |
# | Dataset B | `day2_practical_2_1_dataset_n1000_right_skew.csv` | 1000 |
#
# </div>

# %%
# Read the CSV files

dataset_a = pd.read_csv("day2_practical_2_1_dataset_n25_left_skew.csv")
dataset_b = pd.read_csv("day2_practical_2_1_dataset_n1000_right_skew.csv")

display(dataset_a.head())
display(dataset_b.head())

# %%
# Check the number of cases

print("Number of cases in Dataset A:", len(dataset_a))
print("Number of cases in Dataset B:", len(dataset_b))

# %% [markdown]
# ## <span style="color:#2563EB"><strong>Plot the DSC distributions</strong></span>
#
# Create histograms for both datasets.
#
# Each plot should include:
#
# - the DSC distribution;
# - the mean DSC;
# - the median DSC;
# - clear axis labels;
# - a title.
#
# Try to write the plotting code yourself. You may use `plt.hist()` and `plt.axvline()`.

# %% [markdown]
# <div style="background-color:#FFF7ED; padding:12px; border-radius:8px">
#
# <span style="color:#F59E0B"><strong>Hint</strong></span>
#
# Start by extracting the `DSC` column from the dataframe.
#
# Then calculate the mean and median, and add them as vertical lines to the histogram.
#
# </div>

# %%
# TODO:
# Plot Dataset A

values = dataset_a["DSC"]

# Calculate mean and median
# Create histogram
# Add vertical lines for mean and median
# Add axis labels, title, and legend

# %%
# TODO:
# Plot Dataset B

values = dataset_b["DSC"]

# Calculate mean and median
# Create histogram
# Add vertical lines for mean and median
# Add axis labels, title, and legend

# %% [markdown]
# ## <span style="color:#2563EB"><strong>Calculate SD and SE</strong></span>
#
# For each dataset, calculate:
#
# - mean DSC;
# - median DSC;
# - standard deviation (SD);
# - standard error (SE).
#
# You may use pandas or NumPy functions.
#
# The SE should reflect how precisely the mean DSC is estimated from the available test cases.

# %% [markdown]
# <div style="background-color:#FFF7ED; padding:12px; border-radius:8px">
#
# <span style="color:#F59E0B"><strong>Hint</strong></span>
#
# The SD describes case-to-case variability.
#
# The SE depends on both the SD and the number of test cases.
#
# </div>

# %%
# TODO:
# Calculate mean, median, SD, and SE for Dataset A

values_a = dataset_a["DSC"]
n_a = len(values_a)

# Your code here

# %%
# TODO:
# Calculate mean, median, SD, and SE for Dataset B

values_b = dataset_b["DSC"]
n_b = len(values_b)

# Your code here

# %%
# TODO:
# Create a summary table for Practical 2.1

# The table should include:
# Dataset name, n, mean DSC, median DSC, SD, SE

# %% [markdown]
# # <span style="color:#2563EB"><strong>Practical 2.2: Confidence Intervals for Model Performance</strong></span>
#
# In this practical, you will compare five algorithms across four test-set examples.
#
# Two examples are segmentation tasks, where performance is measured using mean DSC.
#
# Two examples are classification tasks, where performance is measured using Accuracy.
#
# In every dataset, `alg_03` is the <span style="color:#059669"><strong>proposed method</strong></span>.

# %% [markdown]
# <div style="background-color:#EFF6FF; padding:12px; border-radius:8px">
#
# <span style="color:#2563EB"><strong>Datasets</strong></span>
#
# | Dataset | Filename | Task | Sample size |
# |---|---|---:|---:|
# | Segmentation, small test set | `day2_practical_2_2_segmentation_n50.csv` | Segmentation | 50 |
# | Segmentation, large test set | `day2_practical_2_2_segmentation_n5000.csv` | Segmentation | 5000 |
# | Binary classification, small test set | `day2_practical_2_2_binary_classification_n20.csv` | Classification | 20 |
# | Multiclass classification, large test set | `day2_practical_2_2_multiclass_classification_n1000.csv` | Classification | 1000 |
#
# </div>

# %%
# Read the four Practical 2.2 datasets

segmentation_small = pd.read_csv("day2_practical_2_2_segmentation_n50.csv")
segmentation_large = pd.read_csv("day2_practical_2_2_segmentation_n5000.csv")

classification_binary_small = pd.read_csv("day2_practical_2_2_binary_classification_n20.csv")
classification_multiclass_large = pd.read_csv("day2_practical_2_2_multiclass_classification_n1000.csv")

display(segmentation_small.head())
display(segmentation_large.head())
display(classification_binary_small.head())
display(classification_multiclass_large.head())

# %%
algorithms = ["alg_01", "alg_02", "alg_03", "alg_04", "alg_05"]
proposed_algorithm = "alg_03"

# %%
# Helper function for displaying the proposed method in bold

def bold_proposed_method(row):
    if row.name == proposed_algorithm:
        return ["font-weight: bold"] * len(row)
    return [""] * len(row)

# %% [markdown]
# ## <span style="color:#2563EB"><strong>Publication-style performance tables</strong></span>
#
# Create one table per dataset.
#
# For segmentation datasets, report mean DSC.
#
# For classification datasets, report Accuracy.
#
# The proposed method should be displayed in **bold**.

# %% [markdown]
# <div style="background-color:#FFF7ED; padding:12px; border-radius:8px">
#
# <span style="color:#F59E0B"><strong>Hints</strong></span>
#
# - In segmentation datasets, each algorithm column already contains case-wise DSC values.
# - In classification datasets, compare each algorithm's predictions with `ground_truth`.
# - Store one result per algorithm and convert the results into a pandas dataframe.
# - Set the algorithm column as the index before styling the proposed method.
#
# </div>

# %%
# TODO:
# Write a function that creates a publication-style table
# for a segmentation dataset.

def segmentation_performance_table(dataset):
    # Your code here
    pass

# %%
# TODO:
# Write a function that creates a publication-style table
# for a classification dataset.

def classification_performance_table(dataset):
    # Your code here
    pass

# %%
# TODO:
# Generate initial performance table: Segmentation, n = 50

# %%
# TODO:
# Generate initial performance table: Segmentation, n = 5000

# %%
# TODO:
# Generate initial performance table: Binary classification, n = 20

# %%
# TODO:
# Generate initial performance table: Multiclass classification, n = 1000

# %% [markdown]
# ## <span style="color:#2563EB"><strong>Bootstrap confidence intervals for individual model performance</strong></span>
#
# Now estimate uncertainty around individual model performance.
#
# Use **1000 bootstrap resamplings**.
#
# For each bootstrap resampling:
#
# 1. sample cases from the test set with replacement;
# 2. calculate the performance metric;
# 3. store the result.
#
# After repeating this many times, summarize the bootstrap distribution.

# %% [markdown]
# <div style="background-color:#FFF7ED; padding:12px; border-radius:8px">
#
# <span style="color:#F59E0B"><strong>Hints</strong></span>
#
# - A bootstrap sample should have the same number of rows as the original test set.
# - Sampling should be done with replacement.
# - `np.random.default_rng()` can help make the procedure reproducible.
# - Percentiles of the bootstrap estimates can be used to construct a confidence interval.
#
# </div>

# %%
# TODO:
# Implement bootstrap confidence intervals for mean DSC.

def bootstrap_mean_dsc(dataset, algorithm, n_bootstrap=1000, random_state=42):
    # Your code here
    pass

# %%
# TODO:
# Implement bootstrap confidence intervals for Accuracy.

def bootstrap_accuracy(dataset, algorithm, n_bootstrap=1000, random_state=42):
    # Your code here
    pass

# %%
# Optional helper for formatting a mean and confidence interval

def format_mean_ci(mean_value, ci_lower, ci_upper):
    return f"{mean_value:.3f} ({ci_lower:.3f}, {ci_upper:.3f})"

# %%
# TODO:
# Create final segmentation table with bootstrap confidence intervals.

def segmentation_table_with_ci(dataset):
    # Your code here
    pass

# %%
# TODO:
# Create final classification table with bootstrap confidence intervals.

def classification_table_with_ci(dataset):
    # Your code here
    pass

# %%
# TODO:
# Generate final performance table with CI: Segmentation, n = 50

# %%
# TODO:
# Generate final performance table with CI: Segmentation, n = 5000

# %%
# TODO:
# Generate final performance table with CI: Binary classification, n = 20

# %%
# TODO:
# Generate final performance table with CI: Multiclass classification, n = 1000

# %% [markdown]
# # <span style="color:#2563EB"><strong>Practical 2.3: Confidence Intervals for Differences in Model Performance</strong></span>
#
# In Practical 2.2, you computed confidence intervals for the performance of individual models.
#
# In this practical, you will compare the proposed method directly against each comparator.
#
# Use `alg_03` as the proposed method.

# %% [markdown]
# <div style="background-color:#EFF6FF; padding:12px; border-radius:8px">
#
# <span style="color:#2563EB"><strong>Goal</strong></span>
#
# For each dataset, construct a table with:
#
# - one row per comparison;
# - the point estimate of the performance difference;
# - the mean performance difference across bootstrap resamplings;
# - a 95% confidence interval for the performance difference.
#
# </div>

# %%
comparators = [alg for alg in algorithms if alg != proposed_algorithm]
comparators

# %% [markdown]
# <div style="background-color:#FFF7ED; padding:12px; border-radius:8px">
#
# <span style="color:#F59E0B"><strong>Hints</strong></span>
#
# - Reuse the bootstrap logic from Practical 2.2.
# - In each bootstrap sample, calculate performance for the proposed method and for one comparator.
# - Store the difference between these two performance values.
# - Repeat this for all comparator algorithms.
# - Repeat the same logic separately for segmentation and classification datasets.
#
# </div>

# %%
# TODO:
# Implement bootstrap confidence intervals for differences in mean DSC.

def bootstrap_difference_mean_dsc(dataset, proposed_algorithm, comparator_algorithm, n_bootstrap=1000, random_state=42):
    # Your code here
    pass

# %%
# TODO:
# Create a table of DSC differences for one segmentation dataset.

def segmentation_difference_table(dataset):
    # Your code here
    pass

# %%
# TODO:
# Implement bootstrap confidence intervals for differences in Accuracy.

def bootstrap_difference_accuracy(dataset, proposed_algorithm, comparator_algorithm, n_bootstrap=1000, random_state=42):
    # Your code here
    pass

# %%
# TODO:
# Create a table of Accuracy differences for one classification dataset.

def classification_difference_table(dataset):
    # Your code here
    pass

# %%
# TODO:
# Generate performance difference table: Segmentation, n = 50

# %%
# TODO:
# Generate performance difference table: Segmentation, n = 5000

# %%
# TODO:
# Generate performance difference table: Binary classification, n = 20

# %%
# TODO:
# Generate performance difference table: Multiclass classification, n = 1000
