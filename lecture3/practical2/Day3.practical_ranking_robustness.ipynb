# %% [markdown]
# # <span style="color:#2563EB"><strong>Day 3 — Ranking Robustness</strong></span>
#
# This notebook contains one short practical exercise:
#
# - Practical 2.1: How rankings change when aggregating case-level DSC scores by mean versus median
#
# The aim is to analyze ranking robustness by using different aggregation operators.

# %%
# Required packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # <span style="color:#2563EB"><strong>Practical 2.1: Aggregation Operators</strong></span>
#
# In this practical, you will work with two example segmentation datasets of Dice Similarity Values (**DSC**).

# %%
# Read the CSV file
results = pd.read_csv("data_day3_practical_2_1.csv")

# %%
# Check the dataset dimensions
print("Number of algorithms:", results["algorithm"].nunique())
print("Number of cases:", results["case"].nunique())

# %% [markdown]
# ## <span style="color:#2563EB"><strong>Aggregate DSC scores per algorithm</strong></span>
#
# Calculate the mean and median DSC for each algorithm.
#
# Then rank the algorithms twice:
#
# - once by mean DSC;
# - once by median DSC.

# %% [markdown]
# <div style="background-color:#FFF7ED; padding:12px; border-radius:8px">
#
# <span style="color:#F59E0B"><strong>Hint</strong></span>
#
# Use `groupby()` and `agg()` to calculate both summary statistics.
#
# You can use `rank(ascending=False)` as higher DSC values correspond to better results.
#
# </div>

# %%
# TODO:
# 1. Calculate the mean DSC per algorithm
# 2. Calculate the median DSC per algorithm
# 3. Create a summary table containing:
#       - algorithm
#       - mean_dsc
#       - median_dsc
# 4. Rank algorithms based on:
#       - mean DSC
#       - median DSC
# 5. Sort the table by the mean-based ranking

# %% [markdown]
# ## <span style="color:#2563EB"><strong>Visualize the results</strong></span>
#
# Plot the DSC distributions for all algorithms (boxplots).

# %%
# TODO:
# Create boxplots of DSC scores for all algorithms
