# %% [markdown]
# ## <span style="color:#2563EB"><strong>Practical 1.1: Validating a Classification Model - Part 1</strong></span>

# %% [markdown]
# ### Exercise 1
#
# We evaluate a binary classification model on a dataset containing **100 patients**.
# The goal is to classify each patient as either:
#
# - **Class 1:** sick
# - **Class 0:** healthy
#
# In the dataset:
#
# | Class | Number of patients |
# |---|---:|
# | Healthy, Class 0 | 97 |
# | Sick, Class 1 | 3 |
#
# The confusion matrix of the model is shown below.
#
# |                  | Predicted: Class 1 | Predicted: Class 0 |
# |------------------|-------------------:|-------------------:|
# | Actual: Class 1  | TP = 0             | FN = 3             |
# | Actual: Class 0  | FP = 0             | TN = 97            |

# %%
import numpy as np

# %% [markdown]
# ### <span style="color:#2563EB"><strong>Compute the Accuracy of the Model</strong></span>
#
# For the given example, compute the Accuracy by filling in the missing code below.

# %%
# Confusion matrix values

TN = 97
FP = 0
FN = 3
TP = 0

# TODO:
# Compute Accuracy

accuracy = 

print(f"Accuracy: {accuracy:.2f}")

# %% [markdown]
# ### <span style="color:#2563EB"><strong>Compute Further Metrics of the Model</strong></span>

# %%
# Confusion matrix values

TN = 97
FP = 0
FN = 3
TP = 0

# TODO:
# Compute Sensitivity

sensitivity = 

# TODO:
# Compute Specificity

specificity = 

# TODO:
# Compute Balanced Accuracy

balanced_accuracy = 

print(f"Sensitivity: {sensitivity:.2f}")
print(f"Specificity: {specificity:.2f}")
print(f"Balanced Accuracy: {balanced_accuracy:.2f}")

# %% [markdown]
# ## <span style="color:#2563EB"><strong>Practical 1.2: Validating a Classification Model - Part 2</strong></span>
#
# ### Exercise 2
#
# Now consider a second model evaluated on a much larger dataset.
#
# The confusion matrix is shown below.
#
# |                  | Predicted: Class 1 | Predicted: Class 0 |
# |------------------|-------------------:|-------------------:|
# | Actual: Class 1  | TP = 15            | FN = 5             |
# | Actual: Class 0  | FP = 4980          | TN = 95000         |

# %% [markdown]
# ### <span style="color:#2563EB"><strong>Calculate PPV, Accuracy, and Balanced Accuracy</strong></span>

# %%
# Confusion matrix values

TP = 15
FN = 5
FP = 4980
TN = 95000

# TODO:
# Compute Positive Predictive Value

ppv = 

# TODO:
# Compute Accuracy

accuracy = 

# TODO:
# Compute Sensitivity

sensitivity = 

# TODO:
# Compute Specificity

specificity = 

# TODO:
# Compute Balanced Accuracy

balanced_accuracy = 

print(f"PPV: {ppv:.4f}")
print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Balanced Accuracy: {balanced_accuracy:.4f}")
